# %% [markdown]
# Capital Gain Tracker

# %%
from stock_ledger import StockLedger

# %%
# Create stock ledger 
ledger = StockLedger() 

# Buying stocks 
ledger.buy("AAPL", 20, 45) 
ledger.buy("AAPL", 20, 75) 
ledger.buy("MSFT", 20, 95) 

# Display ledger after buying 
print("Stock Ledger after buying:") 
ledger.display_ledger() 
print("---") 

# Selling stocks 
ledger.sell("AAPL", 30, 65) 

# Display ledger after buying 
print("Stock Ledger after buying:") 
ledger.display_ledger() 
print("---") 

# Selling stocks 
ledger.sell("AAPL", 10, 65) 

# Display ledger after buying 
print("Stock Ledger after buying:") 
ledger.display_ledger() 
print("---") 

# Buying stocks 
ledger.buy("AAPL", 100, 20) 
ledger.buy("AAPL", 20, 24) 
ledger.buy("TSLA", 200, 36) 

# Display ledger after buying 
print("Stock Ledger after buying:") 
ledger.display_ledger() 
print("---") 

# Selling stocks 
ledger.sell("AAPL", 10, 65) 

# Display ledger after buying 
print("Stock Ledger after buying:") 
ledger.display_ledger() 
print("---") 

# Selling stocks 
ledger.sell("TSLA", 150, 30) 

# Display ledger after buying 
print("Stock Ledger after buying:") 
ledger.display_ledger() 
print("---") 

# Buying stocks 
ledger.buy("MSFT", 5, 60) 
ledger.buy("MSFT", 5, 70) 

# Display ledger after buying 
print("Stock Ledger after buying:") 
ledger.display_ledger() 
print("---") 

# Selling stocks 
ledger.sell("MSFT", 4, 30) 

# Display ledger after buying 
print("Stock Ledger after buying:") 
ledger.display_ledger() 
print("---") 

# Selling stocks 
ledger.sell("MSFT", 2, 30) 


# Display ledger after selling 
print("Stock Ledger after selling:") 
ledger.display_ledger()
# Out:
# Stock Ledger after buying:
# AAPL: 20 shares @ 45.00, 20 shares @ 75.00
# MSFT: 20 shares @ 95.00
# ---
# Sold 30 shares of AAPL for a total of $1950.00
# Stock Ledger after buying:
# AAPL: 10 shares @ 75.00
# MSFT: 20 shares @ 95.00
# ---
# Sold 10 shares of AAPL for a total of $650.00
# Stock Ledger after buying:
# AAPL:
# MSFT: 20 shares @ 95.00
# ---
# Stock Ledger after buying:
# AAPL: 100 shares @ 20.00, 20 shares @ 24.00
# MSFT: 20 shares @ 95.00
# TSLA: 200 shares @ 36.00
# ---
# Sold 10 shares of AAPL for a total of $650.00
# Stock Ledger after buying:
# AAPL: 90 shares @ 20.00, 20 shares @ 24.00
# MSFT: 20 shares @ 95.00
# TSLA: 200 shares @ 36.00
# ---
# Sold 150 shares of TSLA for a total of $4500.00
# Stock Ledger after buying:
# AAPL: 90 shares @ 20.00, 20 shares @ 24.00
# MSFT: 20 shares @ 95.00
# TSLA: 50 shares @ 36.00
# ---
# Stock Ledger after buying:
# AAPL: 90 shares @ 20.00, 20 shares @ 24.00
# MSFT: 20 shares @ 95.00, 5 shares @ 60.00, 5 shares @ 70.00
# ...
